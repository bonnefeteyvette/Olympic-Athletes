# %% [raw]
# title: "Olympic Athlete Data Analysis"
# author:
#   - name: "INEZA ELIANE"
#     affiliation: "Data Science Group Member"
#   - name: "DENYSE"
#     affiliation: "Data Science Group Member"
#   - name: "BONFETTE"
#     affiliation: "Data Science Group Member"
# date: "2025-06-09"
# format:
#   revealjs:
#     fig-width: 8
#     fig-height: 4
#     theme: solarized
#     slide-number: true
#     toc: false
#     code-fold: true
#     fig-align: center
#     code-summary: "View Code"
# execute:
#   eval: true
#   echo: true
#   warning: false
#   message: false
# ---

# %% [markdown]
# ## Olympic Athlete Data Analysis

# %%
import pandas as pd
import numpy as np
import re

# %%
bio_info=pd.read_csv("Biological Data.csv")

# %%
bio_info
# Out:
#        Athlete ID                                      Roles   Sex  \
# 0             1.0                  Competed in Olympic Games  Male
# 1             2.0                  Competed in Olympic Games  Male
# 2             3.0  Competed in Olympic Games • Administrator  Male
# 3             4.0                  Competed in Olympic Games  Male
# 4             5.0                  Competed in Olympic Games  Male
# ...           ...                                        ...   ...
# 49762     49996.0                  Competed in Olympic Games  Male
# 49763     49997.0                  Competed in Olympic Games  Male
# 49764     49998.0                  Competed in Olympic Games  Male
# 49765     49999.0                  Competed in Olympic Games  Male
# 49766     50000.0                  Competed in Olympic Games  Male
#
#                                                Full Name  \
# 0      François Joseph Marie Antoine "Jean-François"•...
# 1                                Arnaud Benjamin•Boetsch
# 2                            Jean Laurent Robert•Borotra
# 3                   Jacques Marie Stanislas Jean•Brugnon
# 4                                     Henry Albert•Canet
# ...                                                  ...
# 49762                                Aubrey Martin•Bürer
# 49763                              Kenneth Philip•Cawood
# 49764                         Desmond Vernon "Des"•Cohen
# 49765                               Darryl Melwyn•Cronje
# 49766                                   Brendon•Dedekind
#
#                    Used Name Other Names  \
# 0      Jean-François•Blanchy         NaN
# 1             Arnaud•Boetsch         NaN
# 2               Jean•Borotra         NaN
# 3            Jacques•Brugnon         NaN
# 4               Albert•Canet         NaN
# ...                      ...         ...
# 49762           Aubrey•Bürer         NaN
# 49763         Kenneth•Cawood         NaN
# 49764              Des•Cohen         NaN
# 49765          Darryl•Cronje         NaN
# 49766       Brendon•Dedekind         NaN
#
#                                                     Born  \
# 0            12 December 1886 in Bordeaux, Gironde (FRA)
# 1                 1 April 1969 in Meulan, Yvelines (FRA)
# 2      13 August 1898 in Biarritz, Pyrénées-Atlantiqu...
# 3                11 May 1895 in Paris VIIIe, Paris (FRA)
# 4             17 April 1878 in Wandsworth, England (GBR)
# ...                                                  ...
# 49762       13 March 1939 in Johannesburg, Gauteng (RSA)
# 49763                                          05-Jul-71
# 49764                           8 August 1927 in ? (RSA)
# 49765       4 August 1967 in Durban, KwaZulu-Natal (RSA)
# 49766  14 February 1976 in Pietermaritzburg, KwaZulu-...
#
#                                                     Died Height (cm)  \
# 0      2 October 1960 in Saint-Jean-de-Luz, Pyrénées-...         NaN
# 1                                                    NaN      183 cm
# 2      17 July 1994 in Arbonne, Pyrénées-Atlantiques ...      183 cm
# 3                  20 March 1978 in Monaco, Monaco (MON)      168 cm
# 4                25 July 1930 in Paris VIIe, Paris (FRA)         NaN
# ...                                                  ...         ...
# 49762                                                NaN      183 cm
# 49763                                                NaN         NaN
# 49764                                          24-Feb-12         NaN
# 49765                                                NaN         NaN
# 49766                                                NaN      186 cm
#
#       Weight (kg) Measurements                         Affiliations  \
# 0             NaN          NaN                                  NaN
# 1           76 kg          NaN   Racing Club de France, Paris (FRA)
# 2           76 kg          NaN                     TCP, Paris (FRA)
# 3           64 kg          NaN  Sporting club de Paris, Paris (FRA)
# 4             NaN          NaN                     TCP, Paris (FRA)
# ...           ...          ...                                  ...
# 49762       72 kg          NaN           SMU Mustangs, Dallas (USA)
# 49763         NaN          NaN                                  NaN
# 49764         NaN          NaN                                  NaN
# 49765         NaN          NaN                                  NaN
# 49766       90 kg          NaN               Pietermaritzburg Seals
#
#                 NOC
# 0            France
# 1            France
# 2            France
# 3            France
# 4            France
# ...             ...
# 49762  South Africa
# 49763  South Africa
# 49764  South Africa
# 49765  South Africa
# 49766  South Africa
#
# [49767 rows x 13 columns]

# %%
# Step 3: Helper function to split birth/death info
def split_birth_death_info(column):
    dates, cities, regions, countries = [], [], [], []
    for entry in column.fillna("").astype(str):
        if 'in' in entry:
            date_part, location_part = entry.split('in', 1)
            date = date_part.strip()
            location = location_part.strip()
            try:
                city, rest = location.split(',', 1)
                region, country = rest.rsplit('(', 1)
                country = country.replace(')', '').strip()
                cities.append(city.strip())
                regions.append(region.strip())
                countries.append(country.strip())
            except ValueError:
                cities.append(np.nan)
                regions.append(np.nan)
                countries.append(np.nan)
            dates.append(date)
        else:
            dates.append(np.nan)
            cities.append(np.nan)
            regions.append(np.nan)
            countries.append(np.nan)
    return dates, cities, regions, countries

# Step 4: Apply to Born and Died columns
born_dates, born_cities, born_regions, born_countries = split_birth_death_info(bio_info['Born'])
died_dates, died_cities, died_regions, died_countries = split_birth_death_info(bio_info['Died'])

# Step 5: Create new columns
bio_info['Date of Birth'] = born_dates
bio_info['City of Birth'] = born_cities
bio_info['Region of Birth'] = born_regions
bio_info['Country of Birth'] = born_countries

bio_info['Date of Death'] = died_dates
bio_info['City of Death'] = died_cities
bio_info['Region of Death'] = died_regions
bio_info['Country of Death'] = died_countries

# Step 6: Display selected columns
bio_info[
    [
        'Date of Birth', 'City of Birth', 'Region of Birth', 'Country of Birth',
        'Date of Death', 'City of Death', 'Region of Death', 'Country of Death'
    ]
]
# Step 6: Drop original columns
bio_info.drop(columns=['Born', 'Died'], inplace=True)

# %%
# 1. Drop rows missing Athlete ID (very few)
bio_info = bio_info.dropna(subset=['Athlete ID'])

# 2. Fill missing Roles with 'Unknown'
bio_info['Roles'] = bio_info['Roles'].fillna('Unknown')

# 3. Handle Sex: fill missing with 'Unknown'
bio_info['Sex'] = bio_info['Sex'].fillna('Unknown')

# Fill missing Full Name from Used Name where available
bio_info['Full Name'] = bio_info['Full Name'].fillna(bio_info['Used Name'])

# 10. Fill Affiliations missing with 'Unknown'
bio_info['Affiliations'] = bio_info['Affiliations'].fillna('Unknown')

# 11. Drop rows missing NOC (nationality code)
bio_info = bio_info.dropna(subset=['NOC'])

# 12. Drop rows missing Date of Birth (or optionally fill with a placeholder)
bio_info = bio_info.dropna(subset=['Date of Birth'])

# 13-16. Fill missing City, Region, Country of Birth with 'Unknown'
for col in ['City of Birth', 'Region of Birth', 'Country of Birth']:
    if col in bio_info.columns:
        bio_info[col] = bio_info[col].fillna('Unknown')

# 17-20. Handle Date/City/Region/Country of Death
# Fill missing Date of Death with 'Alive'
bio_info['Date of Death'] = bio_info['Date of Death'].fillna('Alive')

# Fill missing city/region/country of death with 'Unknown'
for col in ['City of Death', 'Region of Death', 'Country of Death']:
    if col in bio_info.columns:
        bio_info[col] = bio_info[col].fillna('Unknown')

# Optional: Create 'is_alive' flag based on Date of Death
bio_info['is_alive'] = bio_info['Date of Death'].apply(lambda x: True if x == 'Alive' else False)

# %%
bio_info.isnull().sum()
# Out:
# Athlete ID              0
# Roles                   0
# Sex                     0
# Full Name               0
# Used Name               0
# Height (cm)             0
# Weight (kg)             0
# Measurements        38347
# Affiliations            0
# NOC                     0
# Date of Birth           0
# City of Birth           0
# Region of Birth         0
# Country of Birth        0
# Date of Death           0
# City of Death           0
# Region of Death         0
# Country of Death        0
# is_alive                0
# Height              38581
# Weight              39472
# dtype: int64

# %%
import pandas as pd
import numpy as np
import re

# --- Step 1: Extract height and weight from Measurements column ---

def extract_height(measurement):
    if pd.isna(measurement):
        return np.nan
    match = re.search(r'(\d{2,3})\s*cm', measurement)
    return float(match.group(1)) if match else np.nan

def extract_weight(measurement):
    if pd.isna(measurement):
        return np.nan
    match = re.search(r'(\d{2,3})\s*kg', measurement)
    return float(match.group(1)) if match else np.nan

bio_info['Height_from_Measurements'] = bio_info['Measurements'].apply(extract_height)
bio_info['Weight_from_Measurements'] = bio_info['Measurements'].apply(extract_weight)

# --- Step 2: Clean Height and Weight columns ---

bio_info['Height (cm)'] = bio_info['Height (cm)'].astype(str).str.replace(' cm', '', regex=False)
bio_info['Height (cm)'] = pd.to_numeric(bio_info['Height (cm)'], errors='coerce')

bio_info['Weight (kg)'] = bio_info['Weight (kg)'].astype(str).str.replace(' kg', '', regex=False)
bio_info['Weight (kg)'] = pd.to_numeric(bio_info['Weight (kg)'], errors='coerce')

# --- Step 3: Fill missing Height and Weight with extracted values ---

bio_info['Height (cm)'] = bio_info['Height (cm)'].fillna(bio_info['Height_from_Measurements'])
bio_info['Weight (kg)'] = bio_info['Weight (kg)'].fillna(bio_info['Weight_from_Measurements'])

# --- Step 4: Fill remaining missing Height and Weight with median ---

bio_info['Height (cm)'] = bio_info['Height (cm)'].fillna(bio_info['Height (cm)'].median())
bio_info['Weight (kg)'] = bio_info['Weight (kg)'].fillna(bio_info['Weight (kg)'].median())

# --- Step 5: Reconstruct Measurements from Height and Weight for missing values ---

def reconstruct_measurement(row):
    if pd.isna(row['Measurements']) or row['Measurements'] == 'Unknown':
        if pd.notna(row['Height (cm)']) and pd.notna(row['Weight (kg)']):
            return f"{int(row['Height (cm)'])} cm / {int(row['Weight (kg)'])} kg"
        else:
            return 'Unknown'
    return row['Measurements']

bio_info['Measurements'] = bio_info.apply(reconstruct_measurement, axis=1)

# --- Step 6: Drop helper columns ---

bio_info = bio_info.drop(columns=['Height_from_Measurements', 'Weight_from_Measurements'])

# --- Optional: Check for remaining missing values ---

print("Missing Height (cm):", bio_info['Height (cm)'].isna().sum())
print("Missing Weight (kg):", bio_info['Weight (kg)'].isna().sum())
print("Missing Measurements:", bio_info['Measurements'].isna().sum())
# Out:
# Missing Height (cm): 0
# Missing Weight (kg): 0
# Missing Measurements: 0

# %%
bio_info = bio_info.drop(columns=['Height', 'Weight'])

# %%
bio_info
# Out:
#        Athlete ID                                      Roles   Sex  \
# 0             1.0                  Competed in Olympic Games  Male
# 1             2.0                  Competed in Olympic Games  Male
# 2             3.0  Competed in Olympic Games • Administrator  Male
# 3             4.0                  Competed in Olympic Games  Male
# 4             5.0                  Competed in Olympic Games  Male
# ...           ...                                        ...   ...
# 49761     49995.0                  Competed in Olympic Games  Male
# 49762     49996.0                  Competed in Olympic Games  Male
# 49764     49998.0                  Competed in Olympic Games  Male
# 49765     49999.0                  Competed in Olympic Games  Male
# 49766     50000.0                  Competed in Olympic Games  Male
#
#                                                Full Name  \
# 0      François Joseph Marie Antoine "Jean-François"•...
# 1                                Arnaud Benjamin•Boetsch
# 2                            Jean Laurent Robert•Borotra
# 3                   Jacques Marie Stanislas Jean•Brugnon
# 4                                     Henry Albert•Canet
# ...                                                  ...
# 49761                   Anthony Wellesley "Tony"•Briscoe
# 49762                                Aubrey Martin•Bürer
# 49764                         Desmond Vernon "Des"•Cohen
# 49765                               Darryl Melwyn•Cronje
# 49766                                   Brendon•Dedekind
#
#                    Used Name  Height (cm)  Weight (kg)    Measurements  \
# 0      Jean-François•Blanchy        177.0         72.0  177 cm / 72 kg
# 1             Arnaud•Boetsch        183.0         76.0  183 cm / 76 kg
# 2               Jean•Borotra        183.0         76.0  183 cm / 76 kg
# 3            Jacques•Brugnon        168.0         64.0  168 cm / 64 kg
# 4               Albert•Canet        177.0         72.0  177 cm / 72 kg
# ...                      ...          ...          ...             ...
# 49761           Tony•Briscoe        177.0         72.0  177 cm / 72 kg
# 49762           Aubrey•Bürer        183.0         72.0  183 cm / 72 kg
# 49764              Des•Cohen        177.0         72.0  177 cm / 72 kg
# 49765          Darryl•Cronje        177.0         72.0  177 cm / 72 kg
# 49766       Brendon•Dedekind        186.0         90.0  186 cm / 90 kg
#
#                               Affiliations           NOC     Date of Birth  \
# 0                                  Unknown        France  12 December 1886
# 1       Racing Club de France, Paris (FRA)        France      1 April 1969
# 2                         TCP, Paris (FRA)        France    13 August 1898
# 3      Sporting club de Paris, Paris (FRA)        France       11 May 1895
# 4                         TCP, Paris (FRA)        France     17 April 1878
# ...                                    ...           ...               ...
# 49761                              Unknown  South Africa     22 April 1939
# 49762           SMU Mustangs, Dallas (USA)  South Africa     13 March 1939
# 49764                              Unknown  South Africa     8 August 1927
# 49765                              Unknown  South Africa     4 August 1967
# 49766               Pietermaritzburg Seals  South Africa  14 February 1976
#
#           City of Birth       Region of Birth Country of Birth  \
# 0              Bordeaux               Gironde              FRA
# 1                Meulan              Yvelines              FRA
# 2              Biarritz  Pyrénées-Atlantiques              FRA
# 3           Paris VIIIe                 Paris              FRA
# 4            Wandsworth               England              GBR
# ...                 ...                   ...              ...
# 49761      Johannesburg               Gauteng              RSA
# 49762      Johannesburg               Gauteng              RSA
# 49764           Unknown               Unknown          Unknown
# 49765            Durban         KwaZulu-Natal              RSA
# 49766  Pietermaritzburg         KwaZulu-Natal              RSA
#
#          Date of Death      City of Death       Region of Death  \
# 0       2 October 1960  Saint-Jean-de-Luz  Pyrénées-Atlantiques
# 1                Alive            Unknown               Unknown
# 2         17 July 1994            Arbonne  Pyrénées-Atlantiques
# 3        20 March 1978             Monaco                Monaco
# 4         25 July 1930         Paris VIIe                 Paris
# ...                ...                ...                   ...
# 49761  1 December 2018            Unknown               Unknown
# 49762            Alive            Unknown               Unknown
# 49764            Alive            Unknown               Unknown
# 49765            Alive            Unknown               Unknown
# 49766            Alive            Unknown               Unknown
#
#       Country of Death  is_alive
# 0                  FRA     False
# 1              Unknown      True
# 2                  FRA     False
# 3                  MON     False
# 4                  FRA     False
# ...                ...       ...
# 49761          Unknown     False
# 49762          Unknown      True
# 49764          Unknown      True
# 49765          Unknown      True
# 49766          Unknown      True
#
# [39706 rows x 19 columns]

# %%
bio_info.to_csv('cleaned_bio_info.csv', index=False)

# %%
biographical_data=bio_info

# %%
biographical_data
# Out:
#        Athlete ID                                      Roles   Sex  \
# 0             1.0                  Competed in Olympic Games  Male
# 1             2.0                  Competed in Olympic Games  Male
# 2             3.0  Competed in Olympic Games • Administrator  Male
# 3             4.0                  Competed in Olympic Games  Male
# 4             5.0                  Competed in Olympic Games  Male
# ...           ...                                        ...   ...
# 49761     49995.0                  Competed in Olympic Games  Male
# 49762     49996.0                  Competed in Olympic Games  Male
# 49764     49998.0                  Competed in Olympic Games  Male
# 49765     49999.0                  Competed in Olympic Games  Male
# 49766     50000.0                  Competed in Olympic Games  Male
#
#                                                Full Name  \
# 0      François Joseph Marie Antoine "Jean-François"•...
# 1                                Arnaud Benjamin•Boetsch
# 2                            Jean Laurent Robert•Borotra
# 3                   Jacques Marie Stanislas Jean•Brugnon
# 4                                     Henry Albert•Canet
# ...                                                  ...
# 49761                   Anthony Wellesley "Tony"•Briscoe
# 49762                                Aubrey Martin•Bürer
# 49764                         Desmond Vernon "Des"•Cohen
# 49765                               Darryl Melwyn•Cronje
# 49766                                   Brendon•Dedekind
#
#                    Used Name  Height (cm)  Weight (kg)    Measurements  \
# 0      Jean-François•Blanchy        177.0         72.0  177 cm / 72 kg
# 1             Arnaud•Boetsch        183.0         76.0  183 cm / 76 kg
# 2               Jean•Borotra        183.0         76.0  183 cm / 76 kg
# 3            Jacques•Brugnon        168.0         64.0  168 cm / 64 kg
# 4               Albert•Canet        177.0         72.0  177 cm / 72 kg
# ...                      ...          ...          ...             ...
# 49761           Tony•Briscoe        177.0         72.0  177 cm / 72 kg
# 49762           Aubrey•Bürer        183.0         72.0  183 cm / 72 kg
# 49764              Des•Cohen        177.0         72.0  177 cm / 72 kg
# 49765          Darryl•Cronje        177.0         72.0  177 cm / 72 kg
# 49766       Brendon•Dedekind        186.0         90.0  186 cm / 90 kg
#
#                               Affiliations           NOC     Date of Birth  \
# 0                                  Unknown        France  12 December 1886
# 1       Racing Club de France, Paris (FRA)        France      1 April 1969
# 2                         TCP, Paris (FRA)        France    13 August 1898
# 3      Sporting club de Paris, Paris (FRA)        France       11 May 1895
# 4                         TCP, Paris (FRA)        France     17 April 1878
# ...                                    ...           ...               ...
# 49761                              Unknown  South Africa     22 April 1939
# 49762           SMU Mustangs, Dallas (USA)  South Africa     13 March 1939
# 49764                              Unknown  South Africa     8 August 1927
# 49765                              Unknown  South Africa     4 August 1967
# 49766               Pietermaritzburg Seals  South Africa  14 February 1976
#
#           City of Birth       Region of Birth Country of Birth  \
# 0              Bordeaux               Gironde              FRA
# 1                Meulan              Yvelines              FRA
# 2              Biarritz  Pyrénées-Atlantiques              FRA
# 3           Paris VIIIe                 Paris              FRA
# 4            Wandsworth               England              GBR
# ...                 ...                   ...              ...
# 49761      Johannesburg               Gauteng              RSA
# 49762      Johannesburg               Gauteng              RSA
# 49764           Unknown               Unknown          Unknown
# 49765            Durban         KwaZulu-Natal              RSA
# 49766  Pietermaritzburg         KwaZulu-Natal              RSA
#
#          Date of Death      City of Death       Region of Death  \
# 0       2 October 1960  Saint-Jean-de-Luz  Pyrénées-Atlantiques
# 1                Alive            Unknown               Unknown
# 2         17 July 1994            Arbonne  Pyrénées-Atlantiques
# 3        20 March 1978             Monaco                Monaco
# 4         25 July 1930         Paris VIIe                 Paris
# ...                ...                ...                   ...
# 49761  1 December 2018            Unknown               Unknown
# 49762            Alive            Unknown               Unknown
# 49764            Alive            Unknown               Unknown
# 49765            Alive            Unknown               Unknown
# 49766            Alive            Unknown               Unknown
#
#       Country of Death  is_alive
# 0                  FRA     False
# 1              Unknown      True
# 2                  FRA     False
# 3                  MON     False
# 4                  FRA     False
# ...                ...       ...
# 49761          Unknown     False
# 49762          Unknown      True
# 49764          Unknown      True
# 49765          Unknown      True
# 49766          Unknown      True
#
# [39706 rows x 19 columns]

# %%
biographical_data.isnull().sum()
# Out:
# Athlete ID          0
# Roles               0
# Sex                 0
# Full Name           0
# Used Name           0
# Height (cm)         0
# Weight (kg)         0
# Measurements        0
# Affiliations        0
# NOC                 0
# Date of Birth       0
# City of Birth       0
# Region of Birth     0
# Country of Birth    0
# Date of Death       0
# City of Death       0
# Region of Death     0
# Country of Death    0
# is_alive            0
# dtype: int64

# %%
result_info=pd.read_excel("Olympic_performance_result.xlsx")

# %%
result_info
# Out:
#         Athlete_ID                 Games          Discipline  \
# 0                1  1912 Summer Olympics              Tennis
# 1                1  1912 Summer Olympics              Tennis
# 2                1  1920 Summer Olympics              Tennis
# 3                1  1920 Summer Olympics              Tennis
# 4                1  1920 Summer Olympics              Tennis
# ...            ...                   ...                 ...
# 109385       49999  1992 Summer Olympics  Swimming(Aquatics)
# 109386       50000  1996 Summer Olympics  Swimming(Aquatics)
# 109387       50000  1996 Summer Olympics  Swimming(Aquatics)
# 109388       50000  2000 Summer Olympics  Swimming(Aquatics)
# 109389       50000  2000 Summer Olympics  Swimming(Aquatics)
#
#                                                 Event             Team  NOC  \
# 0                               Singles, Men(Olympic)              NaN  FRA
# 1                               Doubles, Men(Olympic)   Jean Montariol  FRA
# 2                               Singles, Men(Olympic)              NaN  FRA
# 3                             Doubles, Mixed(Olympic)  Jeanne Vaussard  FRA
# 4                               Doubles, Men(Olympic)  Jacques Brugnon  FRA
# ...                                               ...              ...  ...
# 109385     4 Ã— 100 metres Medley Relay, Men(Olympic)     South Africa  RSA
# 109386              50 metres Freestyle, Men(Olympic)              NaN  RSA
# 109387             100 metres Freestyle, Men(Olympic)              NaN  RSA
# 109388              50 metres Freestyle, Men(Olympic)              NaN  RSA
# 109389  4 Ã— 100 metres Freestyle Relay, Men(Olympic)     South Africa  RSA
#
#         Pos Medal                     As
# 0        17   NaN  Jean-François Blanchy
# 1       DNS   NaN  Jean-François Blanchy
# 2        32   NaN  Jean-François Blanchy
# 3         8   NaN  Jean-François Blanchy
# 4         4   NaN  Jean-François Blanchy
# ...     ...   ...                    ...
# 109385   14   NaN          Darryl Cronje
# 109386    5   NaN       Brendon Dedekind
# 109387   26   NaN       Brendon Dedekind
# 109388    9   NaN       Brendon Dedekind
# 109389   11   NaN       Brendon Dedekind
#
# [109390 rows x 9 columns]

# %%
result_info.isnull().sum()
# Out:
# Athlete_ID        0
# Games          1167
# Discipline        0
# Event             0
# Team          58862
# NOC               0
# Pos               0
# Medal         92765
# As              921
# dtype: int64

# %%
# Split Year and Season from Games
result_info[['Year', 'Season']] = result_info['Games'].str.extract(r'(\d{4})\s+(\w+)', expand=True)

# Convert Year to integer
result_info.dropna(subset=['Year'], inplace=True)
result_info['Year'] = result_info['Year'].astype(int)
result_info
# Out:
#         Athlete_ID                 Games          Discipline  \
# 0                1  1912 Summer Olympics              Tennis
# 1                1  1912 Summer Olympics              Tennis
# 2                1  1920 Summer Olympics              Tennis
# 3                1  1920 Summer Olympics              Tennis
# 4                1  1920 Summer Olympics              Tennis
# ...            ...                   ...                 ...
# 109385       49999  1992 Summer Olympics  Swimming(Aquatics)
# 109386       50000  1996 Summer Olympics  Swimming(Aquatics)
# 109387       50000  1996 Summer Olympics  Swimming(Aquatics)
# 109388       50000  2000 Summer Olympics  Swimming(Aquatics)
# 109389       50000  2000 Summer Olympics  Swimming(Aquatics)
#
#                                                 Event             Team  NOC  \
# 0                               Singles, Men(Olympic)          Unknown  FRA
# 1                               Doubles, Men(Olympic)   Jean Montariol  FRA
# 2                               Singles, Men(Olympic)          Unknown  FRA
# 3                             Doubles, Mixed(Olympic)  Jeanne Vaussard  FRA
# 4                               Doubles, Men(Olympic)  Jacques Brugnon  FRA
# ...                                               ...              ...  ...
# 109385     4 Ã— 100 metres Medley Relay, Men(Olympic)     South Africa  RSA
# 109386              50 metres Freestyle, Men(Olympic)          Unknown  RSA
# 109387             100 metres Freestyle, Men(Olympic)          Unknown  RSA
# 109388              50 metres Freestyle, Men(Olympic)          Unknown  RSA
# 109389  4 Ã— 100 metres Freestyle Relay, Men(Olympic)     South Africa  RSA
#
#          Pos   Medal                     As  Year  Season
# 0       17.0  Failed  Jean-François Blanchy  1912  Summer
# 1       -1.0  Failed  Jean-François Blanchy  1912  Summer
# 2       32.0  Failed  Jean-François Blanchy  1920  Summer
# 3        8.0  Failed  Jean-François Blanchy  1920  Summer
# 4        4.0  Failed  Jean-François Blanchy  1920  Summer
# ...      ...     ...                    ...   ...     ...
# 109385  14.0  Failed          Darryl Cronje  1992  Summer
# 109386   5.0  Failed       Brendon Dedekind  1996  Summer
# 109387  26.0  Failed       Brendon Dedekind  1996  Summer
# 109388   9.0  Failed       Brendon Dedekind  2000  Summer
# 109389  11.0  Failed       Brendon Dedekind  2000  Summer
#
# [108223 rows x 11 columns]

# %%
# Create a new column 'Tied': True if 'Pos' starts with '=', else False
result_info['Tied'] = result_info['Pos'].astype(str).str.startswith('=')

# %%
# Remove leading '=' from Pos column
result_info['Pos'] = result_info['Pos'].astype(str).str.lstrip('=')

# %%
# Convert Pos to numeric: non-numeric values like 'DNF', 'DNS', '' become NaN
result_info['Pos'] = pd.to_numeric(result_info['Pos'], errors='coerce')

# %%
result_info['Games'] = result_info['Games'].fillna("Unknown")
result_info['Team'] = result_info['Team'].fillna("Unknown")
result_info['Medal'] = result_info['Medal'].fillna("Failed")
result_info['As'] = result_info['As'].fillna("Unknown")

# %%
result_info['Pos'] = result_info['Pos'].fillna(-1)  # Use -1 as "did not finish/rank"

# %%
result_info.isnull().sum()
# Out:
# Athlete_ID    0
# Games         0
# Discipline    0
# Event         0
# Team          0
# NOC           0
# Pos           0
# Medal         0
# As            0
# Year          0
# Season        0
# Tied          0
# dtype: int64

# %%
athlete_performance_results=result_info

# %%
athlete_performance_results
# Out:
#         Athlete_ID                 Games          Discipline  \
# 0                1  1912 Summer Olympics              Tennis
# 1                1  1912 Summer Olympics              Tennis
# 2                1  1920 Summer Olympics              Tennis
# 3                1  1920 Summer Olympics              Tennis
# 4                1  1920 Summer Olympics              Tennis
# ...            ...                   ...                 ...
# 109385       49999  1992 Summer Olympics  Swimming(Aquatics)
# 109386       50000  1996 Summer Olympics  Swimming(Aquatics)
# 109387       50000  1996 Summer Olympics  Swimming(Aquatics)
# 109388       50000  2000 Summer Olympics  Swimming(Aquatics)
# 109389       50000  2000 Summer Olympics  Swimming(Aquatics)
#
#                                                 Event             Team  NOC  \
# 0                               Singles, Men(Olympic)          Unknown  FRA
# 1                               Doubles, Men(Olympic)   Jean Montariol  FRA
# 2                               Singles, Men(Olympic)          Unknown  FRA
# 3                             Doubles, Mixed(Olympic)  Jeanne Vaussard  FRA
# 4                               Doubles, Men(Olympic)  Jacques Brugnon  FRA
# ...                                               ...              ...  ...
# 109385     4 Ã— 100 metres Medley Relay, Men(Olympic)     South Africa  RSA
# 109386              50 metres Freestyle, Men(Olympic)          Unknown  RSA
# 109387             100 metres Freestyle, Men(Olympic)          Unknown  RSA
# 109388              50 metres Freestyle, Men(Olympic)          Unknown  RSA
# 109389  4 Ã— 100 metres Freestyle Relay, Men(Olympic)     South Africa  RSA
#
#          Pos   Medal                     As  Year  Season   Tied
# 0       17.0  Failed  Jean-François Blanchy  1912  Summer  False
# 1       -1.0  Failed  Jean-François Blanchy  1912  Summer  False
# 2       32.0  Failed  Jean-François Blanchy  1920  Summer  False
# 3        8.0  Failed  Jean-François Blanchy  1920  Summer  False
# 4        4.0  Failed  Jean-François Blanchy  1920  Summer  False
# ...      ...     ...                    ...   ...     ...    ...
# 109385  14.0  Failed          Darryl Cronje  1992  Summer  False
# 109386   5.0  Failed       Brendon Dedekind  1996  Summer  False
# 109387  26.0  Failed       Brendon Dedekind  1996  Summer  False
# 109388   9.0  Failed       Brendon Dedekind  2000  Summer  False
# 109389  11.0  Failed       Brendon Dedekind  2000  Summer  False
#
# [108223 rows x 12 columns]

# %%
athlete_performance_results.to_csv('Athelete_performance_result_cleaned.csv', index=False)

# %%
athlete_performance_results.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 108223 entries, 0 to 109389
# Data columns (total 12 columns):
#  #   Column      Non-Null Count   Dtype
# ---  ------      --------------   -----
#  0   Athlete_ID  108223 non-null  int64
#  1   Games       108223 non-null  object
#  2   Discipline  108223 non-null  object
#  3   Event       108223 non-null  object
#  4   Team        108223 non-null  object
#  5   NOC         108223 non-null  object
#  6   Pos         108223 non-null  float64
#  7   Medal       108223 non-null  object
#  8   As          108223 non-null  object
#  9   Year        108223 non-null  int32
#  10  Season      108223 non-null  object
#  11  Tied        108223 non-null  bool
# dtypes: bool(1), float64(1), int32(1), int64(1), object(8)
# memory usage: 9.6+ MB

# %%
biographical_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 39706 entries, 0 to 49766
# Data columns (total 19 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Athlete ID        39706 non-null  float64
#  1   Roles             39706 non-null  object
#  2   Sex               39706 non-null  object
#  3   Full Name         39706 non-null  object
#  4   Used Name         39706 non-null  object
#  5   Height (cm)       39706 non-null  float64
#  6   Weight (kg)       39706 non-null  float64
#  7   Measurements      39706 non-null  object
#  8   Affiliations      39706 non-null  object
#  9   NOC               39706 non-null  object
#  10  Date of Birth     39706 non-null  object
#  11  City of Birth     39706 non-null  object
#  12  Region of Birth   39706 non-null  object
#  13  Country of Birth  39706 non-null  object
#  14  Date of Death     39706 non-null  object
#  15  City of Death     39706 non-null  object
#  16  Region of Death   39706 non-null  object
#  17  Country of Death  39706 non-null  object
#  18  is_alive          39706 non-null  bool
# dtypes: bool(1), float64(3), object(15)
# memory usage: 5.8+ MB

# %%
athlete_performance_results=athlete_performance_results.rename(columns={'Athlete_ID': 'Athlete ID'})

# %%
merged_df = pd.merge(biographical_data, athlete_performance_results, on='Athlete ID', how='inner')

# %%
merged_df
# Out:
#        Athlete ID                      Roles   Sex  \
# 0             1.0  Competed in Olympic Games  Male
# 1             1.0  Competed in Olympic Games  Male
# 2             1.0  Competed in Olympic Games  Male
# 3             1.0  Competed in Olympic Games  Male
# 4             1.0  Competed in Olympic Games  Male
# ...           ...                        ...   ...
# 90822     49999.0  Competed in Olympic Games  Male
# 90823     50000.0  Competed in Olympic Games  Male
# 90824     50000.0  Competed in Olympic Games  Male
# 90825     50000.0  Competed in Olympic Games  Male
# 90826     50000.0  Competed in Olympic Games  Male
#
#                                                Full Name  \
# 0      François Joseph Marie Antoine "Jean-François"•...
# 1      François Joseph Marie Antoine "Jean-François"•...
# 2      François Joseph Marie Antoine "Jean-François"•...
# 3      François Joseph Marie Antoine "Jean-François"•...
# 4      François Joseph Marie Antoine "Jean-François"•...
# ...                                                  ...
# 90822                               Darryl Melwyn•Cronje
# 90823                                   Brendon•Dedekind
# 90824                                   Brendon•Dedekind
# 90825                                   Brendon•Dedekind
# 90826                                   Brendon•Dedekind
#
#                    Used Name  Height (cm)  Weight (kg)    Measurements  \
# 0      Jean-François•Blanchy        177.0         72.0  177 cm / 72 kg
# 1      Jean-François•Blanchy        177.0         72.0  177 cm / 72 kg
# 2      Jean-François•Blanchy        177.0         72.0  177 cm / 72 kg
# 3      Jean-François•Blanchy        177.0         72.0  177 cm / 72 kg
# 4      Jean-François•Blanchy        177.0         72.0  177 cm / 72 kg
# ...                      ...          ...          ...             ...
# 90822          Darryl•Cronje        177.0         72.0  177 cm / 72 kg
# 90823       Brendon•Dedekind        186.0         90.0  186 cm / 90 kg
# 90824       Brendon•Dedekind        186.0         90.0  186 cm / 90 kg
# 90825       Brendon•Dedekind        186.0         90.0  186 cm / 90 kg
# 90826       Brendon•Dedekind        186.0         90.0  186 cm / 90 kg
#
#                  Affiliations         NOC_x  ...          Discipline  \
# 0                     Unknown        France  ...              Tennis
# 1                     Unknown        France  ...              Tennis
# 2                     Unknown        France  ...              Tennis
# 3                     Unknown        France  ...              Tennis
# 4                     Unknown        France  ...              Tennis
# ...                       ...           ...  ...                 ...
# 90822                 Unknown  South Africa  ...  Swimming(Aquatics)
# 90823  Pietermaritzburg Seals  South Africa  ...  Swimming(Aquatics)
# 90824  Pietermaritzburg Seals  South Africa  ...  Swimming(Aquatics)
# 90825  Pietermaritzburg Seals  South Africa  ...  Swimming(Aquatics)
# 90826  Pietermaritzburg Seals  South Africa  ...  Swimming(Aquatics)
#
#                                                Event             Team NOC_y  \
# 0                              Singles, Men(Olympic)          Unknown   FRA
# 1                              Doubles, Men(Olympic)   Jean Montariol   FRA
# 2                              Singles, Men(Olympic)          Unknown   FRA
# 3                            Doubles, Mixed(Olympic)  Jeanne Vaussard   FRA
# 4                              Doubles, Men(Olympic)  Jacques Brugnon   FRA
# ...                                              ...              ...   ...
# 90822     4 Ã— 100 metres Medley Relay, Men(Olympic)     South Africa   RSA
# 90823              50 metres Freestyle, Men(Olympic)          Unknown   RSA
# 90824             100 metres Freestyle, Men(Olympic)          Unknown   RSA
# 90825              50 metres Freestyle, Men(Olympic)          Unknown   RSA
# 90826  4 Ã— 100 metres Freestyle Relay, Men(Olympic)     South Africa   RSA
#
#         Pos   Medal                     As  Year  Season   Tied
# 0      17.0  Failed  Jean-François Blanchy  1912  Summer  False
# 1      -1.0  Failed  Jean-François Blanchy  1912  Summer  False
# 2      32.0  Failed  Jean-François Blanchy  1920  Summer  False
# 3       8.0  Failed  Jean-François Blanchy  1920  Summer  False
# 4       4.0  Failed  Jean-François Blanchy  1920  Summer  False
# ...     ...     ...                    ...   ...     ...    ...
# 90822  14.0  Failed          Darryl Cronje  1992  Summer  False
# 90823   5.0  Failed       Brendon Dedekind  1996  Summer  False
# 90824  26.0  Failed       Brendon Dedekind  1996  Summer  False
# 90825   9.0  Failed       Brendon Dedekind  2000  Summer  False
# 90826  11.0  Failed       Brendon Dedekind  2000  Summer  False
#
# [90827 rows x 30 columns]

# %%
All_athelete_performance_result=merged_df

# %%
All_athelete_performance_result
# Out:
#        Athlete ID                      Roles   Sex  \
# 0             1.0  Competed in Olympic Games  Male
# 1             1.0  Competed in Olympic Games  Male
# 2             1.0  Competed in Olympic Games  Male
# 3             1.0  Competed in Olympic Games  Male
# 4             1.0  Competed in Olympic Games  Male
# ...           ...                        ...   ...
# 90822     49999.0  Competed in Olympic Games  Male
# 90823     50000.0  Competed in Olympic Games  Male
# 90824     50000.0  Competed in Olympic Games  Male
# 90825     50000.0  Competed in Olympic Games  Male
# 90826     50000.0  Competed in Olympic Games  Male
#
#                                                Full Name  \
# 0      François Joseph Marie Antoine "Jean-François"•...
# 1      François Joseph Marie Antoine "Jean-François"•...
# 2      François Joseph Marie Antoine "Jean-François"•...
# 3      François Joseph Marie Antoine "Jean-François"•...
# 4      François Joseph Marie Antoine "Jean-François"•...
# ...                                                  ...
# 90822                               Darryl Melwyn•Cronje
# 90823                                   Brendon•Dedekind
# 90824                                   Brendon•Dedekind
# 90825                                   Brendon•Dedekind
# 90826                                   Brendon•Dedekind
#
#                    Used Name  Height (cm)  Weight (kg)    Measurements  \
# 0      Jean-François•Blanchy        177.0         72.0  177 cm / 72 kg
# 1      Jean-François•Blanchy        177.0         72.0  177 cm / 72 kg
# 2      Jean-François•Blanchy        177.0         72.0  177 cm / 72 kg
# 3      Jean-François•Blanchy        177.0         72.0  177 cm / 72 kg
# 4      Jean-François•Blanchy        177.0         72.0  177 cm / 72 kg
# ...                      ...          ...          ...             ...
# 90822          Darryl•Cronje        177.0         72.0  177 cm / 72 kg
# 90823       Brendon•Dedekind        186.0         90.0  186 cm / 90 kg
# 90824       Brendon•Dedekind        186.0         90.0  186 cm / 90 kg
# 90825       Brendon•Dedekind        186.0         90.0  186 cm / 90 kg
# 90826       Brendon•Dedekind        186.0         90.0  186 cm / 90 kg
#
#                  Affiliations         NOC_x  ...          Discipline  \
# 0                     Unknown        France  ...              Tennis
# 1                     Unknown        France  ...              Tennis
# 2                     Unknown        France  ...              Tennis
# 3                     Unknown        France  ...              Tennis
# 4                     Unknown        France  ...              Tennis
# ...                       ...           ...  ...                 ...
# 90822                 Unknown  South Africa  ...  Swimming(Aquatics)
# 90823  Pietermaritzburg Seals  South Africa  ...  Swimming(Aquatics)
# 90824  Pietermaritzburg Seals  South Africa  ...  Swimming(Aquatics)
# 90825  Pietermaritzburg Seals  South Africa  ...  Swimming(Aquatics)
# 90826  Pietermaritzburg Seals  South Africa  ...  Swimming(Aquatics)
#
#                                                Event             Team NOC_y  \
# 0                              Singles, Men(Olympic)          Unknown   FRA
# 1                              Doubles, Men(Olympic)   Jean Montariol   FRA
# 2                              Singles, Men(Olympic)          Unknown   FRA
# 3                            Doubles, Mixed(Olympic)  Jeanne Vaussard   FRA
# 4                              Doubles, Men(Olympic)  Jacques Brugnon   FRA
# ...                                              ...              ...   ...
# 90822     4 Ã— 100 metres Medley Relay, Men(Olympic)     South Africa   RSA
# 90823              50 metres Freestyle, Men(Olympic)          Unknown   RSA
# 90824             100 metres Freestyle, Men(Olympic)          Unknown   RSA
# 90825              50 metres Freestyle, Men(Olympic)          Unknown   RSA
# 90826  4 Ã— 100 metres Freestyle Relay, Men(Olympic)     South Africa   RSA
#
#         Pos   Medal                     As  Year  Season   Tied
# 0      17.0  Failed  Jean-François Blanchy  1912  Summer  False
# 1      -1.0  Failed  Jean-François Blanchy  1912  Summer  False
# 2      32.0  Failed  Jean-François Blanchy  1920  Summer  False
# 3       8.0  Failed  Jean-François Blanchy  1920  Summer  False
# 4       4.0  Failed  Jean-François Blanchy  1920  Summer  False
# ...     ...     ...                    ...   ...     ...    ...
# 90822  14.0  Failed          Darryl Cronje  1992  Summer  False
# 90823   5.0  Failed       Brendon Dedekind  1996  Summer  False
# 90824  26.0  Failed       Brendon Dedekind  1996  Summer  False
# 90825   9.0  Failed       Brendon Dedekind  2000  Summer  False
# 90826  11.0  Failed       Brendon Dedekind  2000  Summer  False
#
# [90827 rows x 30 columns]

# %%
All_athelete_performance_result.to_csv('All athelete performance resultcleaned.csv', index=False)
